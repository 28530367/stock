# %%
from finlab import data, login
from finlab.backtest import sim
login('qKIeim2QE14Eoc05Qb3zELX6W824+Q+MAc47CdXg6rua+fCBewmloAUxuI/fwlJG#free')

pe = data.get('price_earning_ratio:本益比')
rev = data.get('monthly_revenue:當月營收')
rev_ma3 = rev.average(3)
rev_ma12 = rev.average(12)
營業利益成長率 = data.get('fundamental_features:營業利益成長率')
peg = (pe/營業利益成長率)
cond1 = rev_ma3/rev_ma12>1.1
cond2 = rev/rev.shift()>0.9
cond_all = cond1 & cond2
result = peg*cond_all
position = result[result>0].is_smallest(10).reindex(rev.index_str_to_date().index, method='ffill')

rr= sim(position=position, fee_ratio=1.425/1000/3,stop_loss=0.1,upload=True,name='本益成長比', live_performance_start='2021-06-01')
# Out:
# 輸入成功!
#  annualized_rate_of_return sharpe max_drawdown win_ratio
#                     31.03%   1.49      -21.57%    53.41%
#          entry_date  exit_date entry_sig_date exit_sig_date  position  period  \
# stock_id
# 1762 中化生 2020-11-11 2020-12-11     2020-11-10    2020-12-10  0.100000      22
# 2028 威致  2020-11-11 2020-12-11     2020-11-10    2020-12-10  0.100000      22
# 4121 優盛  2020-11-11 2020-12-11     2020-11-10    2020-12-10  0.100000      22
# 5465 富驊  2020-09-11 2020-12-11     2020-09-10    2020-12-10  0.111111      62
# 6116 彩晶  2020-11-11 2020-12-11     2020-11-10    2020-12-10  0.100000      22
# 8104 錸寶  2020-09-11 2020-12-11     2020-09-10    2020-12-10  0.111111      62
# 9958 世紀鋼 2020-11-11 2020-12-11     2020-11-10    2020-12-10  0.100000      22
# 1309 台達化 2020-12-11        NaT     2020-12-10           NaT  0.111111      15
# 1586 和勤  2020-11-11        NaT     2020-11-10           NaT  0.100000      37
# ...
